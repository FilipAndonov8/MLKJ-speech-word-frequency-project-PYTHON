# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd

# %%
url = 'http://analytictech.com/mb021/mlk.htm'
page = requests.get(url)

soup = BeautifulSoup(page.text, 'html')

# %%
mlkj_speech = soup.find_all('p')

# %%
speech_combined = [p.text for p in mlkj_speech]

# %%
string_speech = ' '.join(speech_combined)

# %%
string_speech_cleaned = string_speech.replace('\r\n', ' ')

# %%
string_no_pun = re.sub(r'[^\w\s]', '', string_speech_cleaned)

# %%
speech_lower = string_no_pun.lower()

# %%
speech_broken_out = re.split(r'\s+', speech_lower)

# %%
df = pd.DataFrame(speech_broken_out).value_counts()

# %%
df.to_csv(r'C:\Users\ffandonov\Desktop\PORTFOLIO\PYTHON\Python Projects\Web Scraper + Regular Expression Project\MLKJ_speech_count.csv', header = ["Counts"], index_label = 'Word')
